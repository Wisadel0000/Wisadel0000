# %% [markdown]
# ## 一、编写基于Pytorch的 AlexNet 模型

# %% [markdown]
# **1、AlexNet 模型构建**
#
# AlexNet是2012年ImageNet竞赛冠军获得者Hinton和他的学生Alex Krizhevsky设计的。也是在那年之后，更多的更深的神经网络被提出，比如优秀的vgg,GoogLeNet。 这对于传统的机器学习分类算法而言，已经相当的出色。 AlexNet 的网络结构如下图所示：
#
# ![image.png](attachment:65ed4694-6aee-4d07-a4ea-6ea3a72399d5.png)
#
# **2、任务要求**
#
# 构建出满足打印输出要求结构的 AlexNet 模型。打印效果如下图：
#
# ![image.png](attachment:bbd6fb6f-7e1d-45ec-b76f-20f5b78b6312.png)

# %%
#####在下面完成第1个任务#############

# %% [markdown]
# ## 二、使用迁移学习实现猫狗大战

# %% [markdown]
# 本任务使用的数据集来自 Kaggle 网站上的“Dogs vs. Cats ” 竞赛项目。在这个数据集的训练数据集中一共有 25000 张猫和狗的图片，其中包含 12500 张猫的图片和 12500 张狗的图片。在测试数据集中有12500 张图片。
# 用一个训练好的模型进行细微的调整来解决猫狗的二分类问题。
#
# **1、数据集情况**
#
# 在本实践中我们分别从训练数据集的猫和狗的图片中各抽出500张图片组成一个具有1000张图片的验证数据集。
#
# ![image.png](attachment:0b11b2fd-30b0-4871-a45a-f7ae1429835a.png)
#
# **2、下载已经具备最优参数的模型**
#
# 这个过程我们不需要自行搭建训练模型，比如直接下载vgg16网络模型，方法如下：<br>
# from torchvision import models<br>
# model_tran=models.vgg16(pretrained=True)
#
# 若打印网络结构图，可使用：<br>
# print(model_tran)
#
# **3、对当前迁移过来的模型进行微调**
#
# 尽管问题具有相似性，但每个问题对最后输出的结果会有不一样的要求。调整最多的就是全连接的部分，其基本思路是冻结全连接层之前的全部网络层次，让这些被冻结的参数在模型训练中不进行梯度更新仅仅是没有被冻结的全连接层的全部参数。<br>
# 例如仅修改vgg16最后一层的全连接层为10分类问题,示例如下：<br>
# for param in model.parameters():<br>
#     <span>param.requires_grad=False<br>
# model_tran.classifer[6]=torch.nn.Linear(4096,10)
#
# **4、任务要求**
#
# 以resnet50为网络模型，完成迁移部分的代码，并实现猫狗分类，进行模型调优，使准确率达到90%以上。

# %%
#######核心代码如下##############
import torch
from torchvision import models
def trans_model():
    #在以下begin-end之间完成resnet50模型的下载和迁移过程
    ###############begin################
    
    


    #################end################
    
    return model
